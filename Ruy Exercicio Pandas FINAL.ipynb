# %% [markdown]
# # Introdução à Ciência de Dados - UFPB
# Professor: Yuri Malheiros
#
# ## Pandas

# %% [markdown]
# A partir do dataset `movies.csv` utilize o Pandas para responder as seguintes perguntas:

# %% [markdown]
# ### Qual o gênero de filme mais lucrativo em todo o mundo?

# %%
# ADICIONE O SEU CÓDIGO AQUI
import pandas as pd
import numpy as np

# %%
filmes = pd.read_csv('C:\\Users\\Ruy\\Documents\\movies.csv')
filmes
# Out:
#                            Title    US Gross  Worldwide Gross  US DVD Sales  \
# 0                 The Land Girls    146083.0         146083.0           NaN
# 1         First Love, Last Rites     10876.0          10876.0           NaN
# 2     I Married a Strange Person    203134.0         203134.0           NaN
# 3           Let's Talk About Sex    373615.0         373615.0           NaN
# 4                           Slam   1009819.0        1087521.0           NaN
# ...                          ...         ...              ...           ...
# 3196  Zack and Miri Make a Porno  31452765.0       36851125.0    21240321.0
# 3197                      Zodiac  33080084.0       83080084.0    20983030.0
# 3198                        Zoom  11989328.0       12506188.0     6679409.0
# 3199         The Legend of Zorro  45575336.0      141475336.0           NaN
# 3200           The Mask of Zorro  93828745.0      233700000.0           NaN
#
# ...

# %%
filmes.sort_values(by = "Worldwide Gross", ascending=False)[["Major Genre", "Worldwide Gross"]]
# Out:
#             Major Genre  Worldwide Gross
# 1234             Action     2.767891e+09
# 2970  Thriller/Suspense     1.842880e+09
# 2202          Adventure     1.133027e+09
# 2507          Adventure     1.065660e+09
# 2987          Adventure     1.046341e+09
# ...                 ...              ...
# 266                 NaN              NaN
# 404                 NaN              NaN
# 467                 NaN              NaN
# 1025                NaN              NaN
# 1028                NaN              NaN
#
# [3201 rows x 2 columns]

# %% [markdown]
# ### Qual o diretor dirigiu mais filmes?

# %%
# ADICIONE O SEU CÓDIGO AQUI
pd.value_counts(filmes["Director"])
# Out:
# Steven Spielberg       23
# Woody Allen            16
# Martin Scorsese        15
# Spike Lee              15
# Ridley Scott           14
#                        ..
# Franco Zeffirelli       1
# John Turturro           1
# Shane Acker             1
# Phil Alden Robinson     1
# Vin Diesel              1
# Name: Director, Length: 550, dtype: int64

# %% [markdown]
# ### Quais filmes tiverem os maiores arrecadações (Gross) em relação ao orçamento de produção (Budget)?

# %%
# ADICIONE O SEU CÓDIGO AQUI
filmes["Box Office"] = filmes["Worldwide Gross"] - filmes["Production Budget"]
filmes.sort_values(by = "Box Office", ascending=False)[["Title", "Worldwide Gross","Box Office"]]
# Out:
#                                               Title  Worldwide Gross  \
# 1234                                         Avatar     2.767891e+09
# 2970                                        Titanic     1.842880e+09
# 2202  The Lord of the Rings: The Return of the King     1.133027e+09
# 485                                   Jurassic Park     9.230679e+08
# 1975          Harry Potter and the Sorcerer's Stone     9.764579e+08
# ...                                             ...              ...
# 404                                   Hell's Angels              NaN
# 467                                     Intolerance              NaN
# 1025                                       Waterloo              NaN
# 1028                                          Wings              NaN
# 1271                                      Baby Mama     6.439148e+07
#
#         Box Office
# 1234  2.530891e+09
# 2970  1.642880e+09
# 2202  1.039027e+09
# 485   8.600679e+08
# 1975  8.514579e+08
# ...

# %%
#Teste Concluído.
